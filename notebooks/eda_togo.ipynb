# %%
import sys
import os


sys.path.append(os.path.abspath('/home/kali/Desktop/Git/solar_Radiation_Measurement/src'))

# %%
from eda_funs import *
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Load the third dataset
df3 = load_data('/home/kali/Desktop/git/solar_Radiation_Measurement/data/togo-dapaong_qc.csv')

# %%
# Summary Statistics
summary_stats3 = summary_statistics(df3)
print("Summary Statistics:\n", summary_stats3)
# Out:
# Summary Statistics:
#                   GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      230.555040     151.258469     116.444352     226.144375
# std       322.532347     250.956962     156.520714     317.346938
# min       -12.700000       0.000000       0.000000       0.000000
# 25%        -2.200000       0.000000       0.000000       0.000000
# 50%         2.100000       0.000000       2.500000       4.400000
# 75%       442.400000     246.400000     215.700000     422.525000
# max      1424.000000    1004.500000     805.700000    1380.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      219.568588      27.751788      55.013160       2.368093
# std       307.932510       4.758023      28.778732       1.462668
# min         0.000000      14.900000       3.300000       0.000000
# ...

# %%
# Data Quality Check
missing_values3, outliers3 = data_quality_check(df3)
print("Missing Values:\n", missing_values3)
print("Outliers:\n", outliers3)
# Out:
# Missing Values:
#  GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64
# Outliers:
#  GHI               305
# DNI              1062
# DHI              3415
# ModA              137
# ModB              206
# Tamb                0
# RH                  0
# WS               3510
# WSgust           3915
# WSstdev          5753
# WD                  0
# WDstdev          3362
# BP               1019
# Cleaning          281
# Precipitation    3338
# TModA             153
# TModB             609
# Comments            0
# dtype: int64

# %%
# Time Series Analysis
plot_time_series(df3, ['GHI', 'DNI', 'DHI'], 'Time Series Analysis for Togo')

# %%
# Correlation Analysis
plot_correlation_heatmap(df3, ['GHI', 'DNI', 'DHI', 'TModA', 'TModB'])

# %%
# Wind Analysis
plot_wind_polar(df3)

# %%
# Histogram Analysis
plot_histograms(df3, ['GHI', 'DNI', 'DHI', 'WS'])

# %%
# Z-Score Analysis
z_scores3 = calculate_z_scores(df3)
print("Z-Scores:\n", z_scores3)
# Out:
# Z-Scores:
#                            GHI       DNI       DHI     ModA      ModB  \
# Timestamp
# 2021-10-25 00:01:00 -0.718859 -0.602727 -0.743956 -0.71261 -0.713042
# 2021-10-25 00:02:00 -0.718859 -0.602727 -0.743956 -0.71261 -0.713042
# 2021-10-25 00:03:00 -0.718859 -0.602727 -0.743956 -0.71261 -0.713042
# 2021-10-25 00:04:00 -0.718549 -0.602727 -0.743956 -0.71261 -0.713042
# 2021-10-25 00:05:00 -0.718549 -0.602727 -0.743956 -0.71261 -0.713042
# ...                       ...       ...       ...      ...       ...
# 2022-10-24 23:56:00 -0.717309 -0.602727 -0.743956 -0.71261 -0.713042
# 2022-10-24 23:57:00 -0.717619 -0.602727 -0.743956 -0.71261 -0.713042
# 2022-10-24 23:58:00 -0.717929 -0.602727 -0.743956 -0.71261 -0.713042
# 2022-10-24 23:59:00 -0.718239 -0.602727 -0.743956 -0.71261 -0.713042
# 2022-10-25 00:00:00 -0.718549 -0.602727 -0.743956 -0.71261 -0.713042
#
#                          Tamb        RH        WS    WSgust   WSstdev  \
# Timestamp
# ...

# %%
# Bubble Chart
plot_bubble_chart(df3, 'GHI', 'Tamb', 'WS', 'RH')

# %%
# Data Cleaning
clean_df3 = clean_data(df3)
print("Cleaned Data:\n", clean_df3.head())
# Out:
# Cleaned Data:
#                       GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# Timestamp
# 2021-10-25 05:43:00  0.0  0.0  0.6   1.2   1.2  25.2  92.7  1.8     2.1
# 2021-10-25 05:44:00  0.2  0.0  0.7   1.4   1.4  25.2  92.7  1.4     1.9
# 2021-10-25 05:45:00  0.5  0.0  0.8   1.6   1.6  25.2  92.8  1.5     1.9
# 2021-10-25 05:46:00  0.8  0.0  0.9   1.9   1.9  25.2  92.6  1.6     2.1
# 2021-10-25 05:47:00  1.0  0.0  1.0   2.1   2.1  25.1  92.5  1.6     1.9
#
#                      WSstdev     WD  WDstdev   BP  Cleaning  Precipitation  \
# Timestamp
# 2021-10-25 05:43:00      0.3  225.4      4.8  977         0            0.0
# 2021-10-25 05:44:00      0.4  231.2      5.8  977         0            0.0
# 2021-10-25 05:45:00      0.4  229.9      7.9  977         0            0.0
# 2021-10-25 05:46:00      0.4  230.1      7.0  977         0            0.0
# 2021-10-25 05:47:00      0.4  230.0      7.0  977         0            0.0
#
# ...
