# %%
import sys
import os


sys.path.append(os.path.abspath('/home/kali/Desktop/Git/solar_Radiation_Measurement/src'))

# %%
from eda_funs import *

# %%
# Load the second dataset
df2 = load_data('/home/kali/Desktop/Git/solar_Radiation_Measurement/data/sierraleone-bumbuna.csv')

# %%
# Summary Statistics
summary_stats2 = summary_statistics(df2)
print("Summary Statistics:\n", summary_stats2)
# Out:
# Summary Statistics:
#                   GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      201.957515     116.376337     113.720571     206.643095
# std       298.495150     218.652659     158.946032     300.896893
# min       -19.500000      -7.800000     -17.900000       0.000000
# 25%        -2.800000      -0.300000      -3.800000       0.000000
# 50%         0.300000      -0.100000      -0.100000       3.600000
# 75%       362.400000     107.000000     224.700000     359.500000
# max      1499.000000     946.000000     892.000000    1507.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      198.114691      26.319394      79.448857       1.146113
# std       288.889073       4.398605      20.520775       1.239248
# min         0.000000      12.300000       9.900000       0.000000
# ...

# %%
# Data Quality Check
missing_values2, outliers2 = data_quality_check(df2)
print("Missing Values:\n", missing_values2)
print("Outliers:\n", outliers2)
# Out:
# Missing Values:
#  GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64
# Outliers:
#  GHI              2477
# DNI              7586
# DHI              2986
# ModA             1604
# ModB             2041
# Tamb              192
# RH               4929
# WS               3967
# WSgust           3665
# WSstdev          2410
# WD                  0
# WDstdev          5140
# BP                977
# Cleaning          508
# Precipitation    4067
# TModA             100
# TModB               4
# Comments            0
# dtype: int64

# %%
# Time Series Analysis
plot_time_series(df2, ['GHI', 'DNI', 'DHI'], 'Time Series Analysis for Dataset 2')

# %%
# Correlation Analysis
plot_correlation_heatmap(df2, ['GHI', 'DNI', 'DHI', 'TModA', 'TModB'])

# %%
# Wind Analysis
plot_wind_polar(df2)

# %%
# Histogram Analysis
plot_histograms(df2, ['GHI', 'DNI', 'DHI', 'WS'])

# %%
# Z-Score Analysis
z_scores2 = calculate_z_scores(df2)
print("Z-Scores:\n", z_scores2)
# Out:
# Z-Scores:
#                            GHI       DNI       DHI      ModA      ModB  \
# Timestamp
# 2021-10-30 00:01:00 -0.678931 -0.532701 -0.720500 -0.686758 -0.685782
# 2021-10-30 00:02:00 -0.678931 -0.532701 -0.720500 -0.686758 -0.685782
# 2021-10-30 00:03:00 -0.678931 -0.532701 -0.720500 -0.686758 -0.685782
# 2021-10-30 00:04:00 -0.678931 -0.532243 -0.720500 -0.686758 -0.685782
# 2021-10-30 00:05:00 -0.678931 -0.532701 -0.720500 -0.686758 -0.685782
# ...                       ...       ...       ...       ...       ...
# 2022-10-29 23:56:00 -0.681946 -0.532701 -0.733712 -0.686758 -0.685782
# 2022-10-29 23:57:00 -0.682281 -0.532701 -0.734342 -0.686758 -0.685782
# 2022-10-29 23:58:00 -0.682281 -0.532701 -0.734971 -0.686758 -0.685782
# 2022-10-29 23:59:00 -0.682281 -0.533158 -0.736229 -0.686758 -0.685782
# 2022-10-30 00:00:00 -0.682281 -0.532701 -0.736858 -0.686758 -0.685782
#
#                          Tamb        RH        WS    WSgust   WSstdev  \
# Timestamp
# ...

# %%
# Bubble Chart
plot_bubble_chart(df2, 'GHI', 'Tamb', 'WS', 'RH')

# %%
# Data Cleaning
clean_df2 = clean_data(df2)
print("Cleaned Data:\n", clean_df2.head())
# Out:
# Cleaned Data:
#                        GHI  DNI   DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# Timestamp
# 2021-10-30 07:13:00  17.7  0.0  17.7  20.1  19.2  22.0  98.6  0.2     0.7
# 2021-10-30 07:14:00  18.3  0.0  18.3  20.7  19.9  22.0  98.5  0.1     0.7
# 2021-10-30 07:15:00  18.9  0.0  18.9  21.4  20.5  22.0  98.6  0.2     0.7
# 2021-10-30 07:16:00  19.5  0.0  19.5  22.0  21.1  22.0  98.6  0.4     1.4
# 2021-10-30 07:17:00  20.1  0.0  20.1  22.7  21.8  22.0  98.5  0.1     1.1
#
#                      WSstdev     WD  WDstdev    BP  Cleaning  Precipitation  \
# Timestamp
# 2021-10-30 07:13:00      0.4  212.8      2.6  1003         0            0.0
# 2021-10-30 07:14:00      0.3  221.4      0.4  1003         0            0.0
# 2021-10-30 07:15:00      0.5  189.1      6.1  1003         0            0.0
# 2021-10-30 07:16:00      0.6  199.4      5.8  1003         0            0.0
# 2021-10-30 07:17:00      0.3  192.0      1.0  1003         0            0.0
#
# ...
